# %% [markdown]
# <a href="https://colab.research.google.com/github/arunuday117/LGMVIP-DataScience/blob/main/Task_2_Image_to_Pencil_Sketch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Lets Grow More**
#
# **Task 2**
#
# **Name : Arun Uday**
#
#
#
# **Data Science Internship**
#
#
#
# **Image to Pencil Sketch with Python**
#
# **Description Of Task :**We need to read the image in RBG format and then convert it to a grayscale image. This will turn an image into a classic black and white photo. Then the next thing to do is invert the grayscale image also called negative image, this will be our inverted grayscale image. Inversion can be used to enhance details. Then we can finally create the pencil sketch by mixing the grayscale image with the inverted blurry image. This can be done by dividing the grayscale image by the inverted blurry image. Since images are just arrays, we can easily do this programmatically using the divide function from the cv2 library in Python.

# %% [markdown]
# # **Importing Libraries**

# %%
import cv2
from matplotlib import pyplot as plt

# %% [markdown]
# **Read the image**

# %%
img = cv2.imread("spidey.jpg")
plt.figure(figsize=(8,8))
plt.imshow(img)
plt.show()

# %% [markdown]
# since the picture is not correctly shown we need to change the image to rgb

# %% [markdown]
# **Converting the image to rgb colors**

# %%
rgb_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.figure(figsize=(8,8))
plt.imshow(rgb_img)
plt.show()

# %% [markdown]
# Now the image shows the right colors

# %% [markdown]
# **Converting the rgb image in to a gray scale image**

# %%
gray_img = cv2.cvtColor(rgb_img, cv2.COLOR_BGR2GRAY)
plt.figure(figsize=(8,8))
plt.imshow(gray_img,cmap='gray')
plt.show()

# %% [markdown]
# This will change the image from rgb to a black and white image

# %% [markdown]
# **Converting the gray scale image in to a inverted image**

# %%
invert_gray_img =255 - gray_img
plt.figure(figsize=(8,8))
plt.imshow(invert_gray_img,cmap='gray')
plt.show()

# %% [markdown]
# Now this will invert the gray scale image into an inverted image which will show more details on the image

# %% [markdown]
# **Bluring the inverted grayscale image using Gaussian Blur**

# %%
blur_img = cv2.GaussianBlur(invert_gray_img, (21,21), 0)
plt.figure(figsize=(8,8))
plt.imshow(blur_img,cmap='gray')
plt.show()

# %% [markdown]
# The Gaussian blur can be used to blur the inverted image and smooth out the image

# %% [markdown]
# **Now inverting the blurred image**

# %%
invert_blur_img = 255 - blur_img
plt.figure(figsize=(8,8))
plt.imshow(invert_blur_img,cmap='gray')
plt.show()

# %% [markdown]
# Now this will invert the blurred image revealing more details on the image

# %% [markdown]
# **Now for the final touch divide the grayscale image with inverted blurred image**

# %%
sketch = cv2.divide(gray_img, invert_blur_img, scale=256.0)
plt.figure(figsize=(8,8))
plt.imshow(rgb_img)
plt.figure(figsize=(8,8))
plt.imshow(sketch,cmap='gray')
plt.show()

# %% [markdown]
# You can see the original image and the final sketched image

# %% [markdown]
# **Thank you**
