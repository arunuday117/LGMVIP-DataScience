# %% [markdown]
# <a href="https://colab.research.google.com/github/arunuday117/LGMVIP-DataScience/blob/main/Task1_Iris_Flower_Classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Lets Grow More**
#
# **Task 1**
#
#
# **Name : Arun Uday**
#
#
# **Data Science Internship**
#
#
# **Iris Flower Classification ML Project**
#
#
# **Description Of Task:**
# This particular ML project is usually referred to as the “Hello World” of Machine Learning. The iris flowers dataset contains numeric attributes, and it is perfect for beginners to learn about supervised ML algorithms, mainly how to load and handle data. Also, since this is a small dataset, it can easily fit in memory without requiring special transformations or scaling capabilities.
#
#
# **Dataset: http://archive.ics.uci.edu/ml/datasets/Iris**

# %% [markdown]
# ## **Importing Libraries**

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import sklearn

# %% [markdown]
# **Importing Dataset**

# %%
column_names=['Sepal_length','Sepal_width','Petal_length','Petal_width','Species']
iris_dataset=pd.read_csv("http://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data",names=column_names)

# %% [markdown]
# Here i have added some column names for the dataset

# %% [markdown]
# **Displaying first 5 rows in the dataset using head()**

# %%
iris_dataset.head()
# Out:
#    Sepal_length  Sepal_width  Petal_length  Petal_width      Species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %% [markdown]
# **Displaying last 5 rows using tail()**

# %%
iris_dataset.tail()
# Out:
#      Sepal_length  Sepal_width  Petal_length  Petal_width         Species
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica

# %% [markdown]
# **describe() displays the statistical aspects of the dataset**

# %%
iris_dataset.describe()
# Out:
#        Sepal_length  Sepal_width  Petal_length  Petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# **shape is used to display the number of columns and rows**

# %%
iris_dataset.shape
# Out:
# (150, 5)

# %% [markdown]
# so here in this dataset we have 150 rows and 5 columns

# %% [markdown]
# **Now using the isnull() to see if there is any null value in the dataset**

# %%
iris_dataset.isnull()
# Out:
#      Sepal_length  Sepal_width  Petal_length  Petal_width  Species
# 0           False        False         False        False    False
# 1           False        False         False        False    False
# 2           False        False         False        False    False
# 3           False        False         False        False    False
# 4           False        False         False        False    False
# ..            ...          ...           ...          ...      ...
# 145         False        False         False        False    False
# 146         False        False         False        False    False
# 147         False        False         False        False    False
# 148         False        False         False        False    False
# 149         False        False         False        False    False
#
# [150 rows x 5 columns]

# %% [markdown]
# **sum() is used to sum the number of rows of each column containing null values**

# %%
iris_dataset.isnull().sum()
# Out:
# Sepal_length    0
# Sepal_width     0
# Petal_length    0
# Petal_width     0
# Species         0
# dtype: int64

# %% [markdown]
# we can see that there is no null value in the dataset

# %% [markdown]
# **Now using the columns we can display the column names of the dataset**

# %%
iris_dataset.columns
# Out:
# Index(['Sepal_length', 'Sepal_width', 'Petal_length', 'Petal_width',
#        'Species'],
#       dtype='object')

# %% [markdown]
# **DataFrame can be used to display the dataset**

# %%
pd.DataFrame(iris_dataset)
# Out:
#      Sepal_length  Sepal_width  Petal_length  Petal_width         Species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# **nunique() is used to see the number of unique rows of each columns**

# %%
iris_dataset.nunique()
# Out:
# Sepal_length    35
# Sepal_width     23
# Petal_length    43
# Petal_width     22
# Species          3
# dtype: int64

# %% [markdown]
# Here i have displayed the unique values of the column species using **unique()**

# %%
unique=iris_dataset.Species.unique().tolist()
unique
# Out:
# ['Iris-setosa', 'Iris-versicolor', 'Iris-virginica']

# %% [markdown]
# **Now to see the number of rows containing each species**

# %%
species_count=iris_dataset.Species.value_counts()
count=species_count.tolist()
species_count.to_frame()
# Out:
#                  Species
# Iris-setosa           50
# Iris-versicolor       50
# Iris-virginica        50

# %% [markdown]
# **max() is used to display the maximum values of each column**

# %%
iris_dataset.max()
# Out:
# Sepal_length               7.9
# Sepal_width                4.4
# Petal_length               6.9
# Petal_width                2.5
# Species         Iris-virginica
# dtype: object

# %% [markdown]
# **min() is used to display the minimum values of each column**

# %%
iris_dataset.min()
# Out:
# Sepal_length            4.3
# Sepal_width               2
# Petal_length              1
# Petal_width             0.1
# Species         Iris-setosa
# dtype: object

# %% [markdown]
# # **Plotting the data**

# %% [markdown]
# **Using piechart**

# %%
plt.pie(count,labels=unique,labeldistance=1,wedgeprops={'linewidth':5,'edgecolor':'white'},autopct="%.02f%%")
plt.title("Number of species with their count", fontsize=20)
plt.show()

# %% [markdown]
# 33.33% of each species is present in the dataset

# %% [markdown]
# **Using boxplot()**

# %%
fig, ax = plt.subplots(figsize=(15,10))
sns.boxplot(data=iris_dataset, width= 0.5, ax=ax, fliersize=3)
plt.show()

# %% [markdown]
# we can clearly see some outliers in the values of sepal width

# %% [markdown]
# **Using scatterplot**

# %%
plt.subplots(figsize=(7,7))
sns.scatterplot(x='Sepal_length',y='Sepal_width',data=iris_dataset,hue='Species');
plt.show()

# %% [markdown]
# versicolor have a medium sepal length and sepal width than the others

# %%
plt.subplots(figsize=(7,7))
sns.scatterplot(x='Petal_length',y='Petal_width',data=iris_dataset,hue='Species');
plt.show()

# %% [markdown]
# Here the species setosa has the lowest petal length and petal width. While virginica has the longest and medium for versicolor.

# %% [markdown]
# **Using pairplot to relate all features with each other**

# %%
plot=sns.pairplot(iris_dataset,hue='Species')
plot.fig.suptitle("Relation of All Feature with Each Other",y=1.2,fontsize=20)
plt.show()

# %% [markdown]
# **Using boxplot to find which species have the highest of each characters**

# %%
plt.figure(figsize=(15,10))
plt.subplot(2,2,1)
sns.barplot(x = 'Species', y = 'Sepal_length', data=iris_dataset)
plt.subplot(2,2,2)
sns.barplot(x = 'Species', y = 'Sepal_width', data=iris_dataset)
plt.subplot(2,2,3)
sns.barplot(x = 'Species', y = 'Petal_length', data=iris_dataset)
plt.subplot(2,2,4)
sns.barplot(x = 'Species', y = 'Petal_width', data=iris_dataset)
plt.show()

# %% [markdown]
# 1.   From the first figure virginica has the longest sepal length
# 2.   From second figure setosa has the widest sepal
# 3.   From third figure virginica has the longest petal
# 4.   From fourth figure virginica has the widest petal

# %% [markdown]
# # **Correlation**

# %%
plt.figure(figsize=(8,5))
sns.heatmap(iris_dataset.corr(),annot=True,cmap="seismic") 
plt.show()

# %% [markdown]
# Heatmap is used to find the maximum and minimum correlation in the dataset

# %% [markdown]
# # **Data Preprocessing**

# %% [markdown]
# **Importing LabelEncoder**

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
iris_dataset['Species'] = le.fit_transform(iris_dataset['Species']) 
iris_dataset.head()
# Out:
#    Sepal_length  Sepal_width  Petal_length  Petal_width  Species
# 0           5.1          3.5           1.4          0.2        0
# 1           4.9          3.0           1.4          0.2        0
# 2           4.7          3.2           1.3          0.2        0
# 3           4.6          3.1           1.5          0.2        0
# 4           5.0          3.6           1.4          0.2        0

# %% [markdown]
# Here i have encoded the values of species column

# %% [markdown]
# Then i have splitted the dataset in to X and Y
#
# X containing columns except species
#
# Y containing species

# %%
X = iris_dataset.drop(columns=['Species'])
Y = iris_dataset['Species'] 
X[:5]
# Out:
#    Sepal_length  Sepal_width  Petal_length  Petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %%
Y[:]
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 145    2
# 146    2
# 147    2
# 148    2
# 149    2
# Name: Species, Length: 150, dtype: int64

# %% [markdown]
# # **Splitting the dataset**

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, random_state = 1)

# %% [markdown]
# Spliting the dataset for training and testing

# %%
X_test.shape
# Out:
# (45, 4)

# %%
X_train.shape
# Out:
# (105, 4)

# %% [markdown]
# # **Training and Testing**

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report

# %%
lr = LogisticRegression(max_iter=1000)
svm = SVC()
dt = DecisionTreeClassifier()
scores=[]

# %% [markdown]
# **Logistic Regression**

# %%
lr.fit(X_train, Y_train)
Y_pred = lr.predict(X_test)
scores.append(accuracy_score(Y_test, Y_pred)) 
print("\n\nAccuracy of " + type(lr).__name__ + " is", accuracy_score(Y_test, Y_pred))
print("\nclassification Report:\n\n ",classification_report(Y_test, Y_pred))
# Out:
# Accuracy of LogisticRegression is 0.9777777777777777
#
# classification Report:
#
#                 precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        14
#            1       1.00      0.94      0.97        18
#            2       0.93      1.00      0.96        13
#
#     accuracy                           0.98        45
#    macro avg       0.98      0.98      0.98        45
# weighted avg       0.98      0.98      0.98        45

# %% [markdown]
# **Support Vector Machine**

# %%
svm.fit(X_train, Y_train)
Y_pred = svm.predict(X_test)
scores.append(accuracy_score(Y_test, Y_pred)) 
print("\n\nAccuracy of " + type(svm).__name__ + " is", accuracy_score(Y_test, Y_pred))
print("\nclassification Report:\n\n ",classification_report(Y_test, Y_pred))
# Out:
# Accuracy of SVC is 0.9777777777777777
#
# classification Report:
#
#                 precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        14
#            1       1.00      0.94      0.97        18
#            2       0.93      1.00      0.96        13
#
#     accuracy                           0.98        45
#    macro avg       0.98      0.98      0.98        45
# weighted avg       0.98      0.98      0.98        45

# %% [markdown]
# **Decision Tree**

# %%
dt.fit(X_train, Y_train)
Y_pred = dt.predict(X_test)
scores.append(accuracy_score(Y_test, Y_pred)) 
print("\n\nAccuracy of " + type(dt).__name__ + " is", accuracy_score(Y_test, Y_pred))
print("\nclassification Report:\n\n ",classification_report(Y_test, Y_pred))
# Out:
# Accuracy of DecisionTreeClassifier is 0.9555555555555556
#
# classification Report:
#
#                 precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        14
#            1       0.94      0.94      0.94        18
#            2       0.92      0.92      0.92        13
#
#     accuracy                           0.96        45
#    macro avg       0.96      0.96      0.96        45
# weighted avg       0.96      0.96      0.96        45

# %%
results = pd.DataFrame({'Models': ['Logistic Regression', 'SVC', 'Decision Tree'],'Accuracy': scores})

results = results.sort_values(by='Accuracy', ascending=False)
print(results)
# Out:
#                 Models  Accuracy
# 0  Logistic Regression  0.977778
# 1                  SVC  0.977778
# 2        Decision Tree  0.955556

# %% [markdown]
# **Thank you**
